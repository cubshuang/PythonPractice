# %% [markdown]
# <a href="https://colab.research.google.com/github/cubshuang/PythonPractice/blob/master/1120407_kmu_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 資料取得來源
#
# https://www.kaggle.com/datasets/saurabhshahane/in-hospital-mortality-prediction

# %%
import pandas as pd
from urllib.request import urlretrieve
url = "https://github.com/Elwing-Chou/kmuml/raw/main/data01.csv"
urlretrieve(url, "data.csv")
data = pd.read_csv("data.csv", encoding="utf-8")
data
# Out:
#       group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0         1  125047      0.0   72        1  37.588179             0
# 1         1  139812      0.0   75        2        NaN             0
# 2         1  109787      0.0   83        2  26.572634             0
# 3         1  130587      0.0   43        2  83.264629             0
# 4         1  138290      0.0   75        2  31.824842             1
# ...     ...     ...      ...  ...      ...        ...           ...
# 1172      2  171130      0.0   62        1  25.516870             1
# 1173      2  101659      0.0   78        1  25.822710             0
# 1174      2  162069      0.0   85        2  23.891779             1
# 1175      2  120967      0.0   79        2  35.288554             0
# 1176      2  107636      0.0   47        1  23.121384             1
#
#       atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                      0               0         1  ...    138.750000
# ...

# %% [markdown]
# hypertensive: Blood pressure higher than 180/120 mm Hg is considered a hypertensive emergency or crisis
#
#
# atrialfibrillation: 心房顫動
#
# CHD with no MI: 冠狀動脈心臟病 with no 心肌梗塞
#
# deficiencyanemias: 缺鐵性貧血(Iron deficiency anemia)是一種常見的貧血
#
# depression: 憂鬱
#
# Hyperlipidemia 認識高脂血症
#
# renal failure: 腎臟 failure
#
# COPD: 慢性阻塞性肺病
#
# Systolic blood pressure: 收縮壓
#
# Diastolic blood pressure: 蘇張壓
#
# Respiratory rate: 呼吸率
#
# SPO2: 血氧飽和度監測
#
# Urine output: 尿尿
#
# hematocrit: 紅血球容積比
#
# RBC: 紅血球計數
#
# MCH: 平均紅血球血紅素
#
# MCHC: 平均紅血球血紅素濃度
#
# MCV: 平均血球容積(MCV)
#
# RDW: 紅血球分布寬度
#
# Leucocyte: White blood cell
#
# Platelets: 血小板計數
#
# Neutrophils: 嗜中性球亦稱嗜中性白血球
#
# Basophils: 嗜鹼性球
#
# Lymphocyte: 淋巴球
#
# PT: 凝血脢原時間
#
# INR: INR =(Patient’s PT/MNPT)ISI, 跟PT有關
#
# NT-proBNP: 定量血漿中的NT-ProBNP，可幫助診斷充血性心衰竭
#
# Creatine kinase: 肌酸激酶
#
# Creatinine: 肌酸酐
#
# Urea nitrogen:  血中尿素氮
#
# glucose: 葡萄糖
#
# Blood potassium: 鉀
#
# Blood sodium: 鈉
#
# Blood calcium: 鈣
#
# Chloride: 氯化物
#
# Anion gap: 陰離子間隙
#
# Magnesium ion: Mg 2+
#
# PH: 酸鹼
#
# Bicarbonate: HCO−3.
#
# Lactic acid: 乳酸
#
# PCO2: CO2分壓
#
# EF: 收縮分率
#
# Target Variable - Outcome
# 0 - Alive
# 1 - Death

# %%
data.columns
# Out:
# Index(['group', 'ID', 'outcome', 'age', 'gendera', 'BMI', 'hypertensive',
#        'atrialfibrillation', 'CHD with no MI', 'diabetes', 'deficiencyanemias',
#        'depression', 'Hyperlipemia', 'Renal failure', 'COPD', 'heart rate',
#        'Systolic blood pressure', 'Diastolic blood pressure',
#        'Respiratory rate', 'temperature', 'SP O2', 'Urine output',
#        'hematocrit', 'RBC', 'MCH', 'MCHC', 'MCV', 'RDW', 'Leucocyte',
#        'Platelets', 'Neutrophils', 'Basophils', 'Lymphocyte', 'PT', 'INR',
#        'NT-proBNP', 'Creatine kinase', 'Creatinine', 'Urea nitrogen',
#        'glucose', 'Blood potassium', 'Blood sodium', 'Blood calcium',
#        'Chloride', 'Anion gap', 'Magnesium ion', 'PH', 'Bicarbonate',
#        'Lactic acid', 'PCO2', 'EF'],
#       dtype='object')

# %%
data = data[data['outcome'].notna()]
data
# Out:
#       group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0         1  125047      0.0   72        1  37.588179             0
# 1         1  139812      0.0   75        2        NaN             0
# 2         1  109787      0.0   83        2  26.572634             0
# 3         1  130587      0.0   43        2  83.264629             0
# 4         1  138290      0.0   75        2  31.824842             1
# ...     ...     ...      ...  ...      ...        ...           ...
# 1172      2  171130      0.0   62        1  25.516870             1
# 1173      2  101659      0.0   78        1  25.822710             0
# 1174      2  162069      0.0   85        2  23.891779             1
# 1175      2  120967      0.0   79        2  35.288554             0
# 1176      2  107636      0.0   47        1  23.121384             1
#
#       atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                      0               0         1  ...    138.750000
# ...

# %%
x = data.drop(["group", "ID", "outcome"], axis=1)
y = data["outcome"].astype(int)

# %%
s = x.isna().sum()
s[s > 0].sort_values(ascending=False)
# Out:
# PCO2                        293
# PH                          291
# Basophils                   259
# Lactic acid                 228
# BMI                         214
# Creatine kinase             165
# Lymphocyte                  145
# Neutrophils                 144
# Urine output                 35
# PT                           20
# INR                          20
# temperature                  18
# glucose                      17
# Diastolic blood pressure     15
# Systolic blood pressure      15
# Respiratory rate             12
# SP O2                        12
# heart rate                   12
# Blood calcium                 1
# dtype: int64

# %%
nu = x.nunique()
categories = set(nu[nu < 5].index)
numbers = set(x.columns) - categories
categories = list(categories)
numbers = list(numbers)
print(categories)
print(numbers)
# Out:
# ['gendera', 'diabetes', 'deficiencyanemias', 'Hyperlipemia', 'COPD', 'CHD with no MI', 'Renal failure', 'hypertensive', 'depression', 'atrialfibrillation']
# ['PCO2', 'Creatine kinase', 'Respiratory rate', 'Urine output', 'MCH', 'Basophils', 'PT', 'Creatinine', 'Lactic acid', 'MCHC', 'RBC', 'glucose', 'Blood potassium', 'Anion gap', 'heart rate', 'BMI', 'RDW', 'Chloride', 'Blood calcium', 'EF', 'age', 'Blood sodium', 'Magnesium ion', 'SP O2', 'Platelets', 'MCV', 'Neutrophils', 'Diastolic blood pressure', 'Leucocyte', 'NT-proBNP', 'hematocrit', 'Lymphocyte', 'Urea nitrogen', 'temperature', 'INR', 'Systolic blood pressure', 'PH', 'Bicarbonate']

# %%
filln = x.median()[numbers]
x = x.fillna(filln)
# check
s = x.isna().sum()
s[s > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
# pd.get_dummies(x, columns=categories)

# %%
y.value_counts()
# Out:
# 0    1017
# 1     159
# Name: outcome, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

scaler = MinMaxScaler()
x_scale = scaler.fit_transform(x)

tsne = TSNE(n_components=2)
x_tsne = tsne.fit_transform(x_scale)

plt.figure(figsize=(8, 8))
x_axis = x_tsne[:, 0]
y_axis = x_tsne[:, 1]
sns.scatterplot(x=x_axis, y=y_axis, hue=y)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
y_test.value_counts()
# Out:
# 0    212
# 1     24
# Name: outcome, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority')
x_s, y_s = smote.fit_resample(x_train, y_train)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

scaler = MinMaxScaler()
x_scale = scaler.fit_transform(x_s)

tsne = TSNE(n_components=2)
x_tsne = tsne.fit_transform(x_scale)

plt.figure(figsize=(10, 10))
x_axis = x_tsne[:, 0]
y_axis = x_tsne[:, 1]
sns.scatterplot(x=x_axis, y=y_axis, hue=y_s)
# Out:
# <Axes: >

# %%
y_train.value_counts()
# Out:
# 0    805
# 1    135
# Name: outcome, dtype: int64

# %%
y_s.value_counts()
# Out:
# 0    805
# 1    805
# Name: outcome, dtype: int64

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=5, n_estimators=100)
clf.fit(x_s, y_s)
pre = clf.predict(x_test)
# threshold = 0.4
# predicted_proba = clf.predict_proba(x_test)
# pre = (predicted_proba [:,1] >= threshold).astype('int')
print(classification_report(y_test, pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       212
#            1       0.36      0.67      0.47        24
#
#     accuracy                           0.85       236
#    macro avg       0.66      0.77      0.69       236
# weighted avg       0.90      0.85      0.87       236

# %%
pd.Series(clf.feature_importances_, index=x.columns).sort_values(ascending=False)
# Out:
# Renal failure               0.093846
# Urine output                0.083851
# deficiencyanemias           0.057082
# Urea nitrogen               0.049340
# Lymphocyte                  0.047709
# Bicarbonate                 0.044034
# Hyperlipemia                0.042878
# PH                          0.039493
# Leucocyte                   0.039381
# Lactic acid                 0.038089
# RDW                         0.029765
# Anion gap                   0.028143
# hypertensive                0.027276
# PT                          0.024426
# INR                         0.019749
# Blood calcium               0.019706
# gendera                     0.019409
# Creatinine                  0.017120
# diabetes                    0.015686
# heart rate                  0.015195
# depression                  0.014973
# PCO2                        0.014028
# Systolic blood pressure     0.013912
# Platelets                   0.013670
# NT-proBNP                   0.013644
# ...

# %%
from imblearn.under_sampling import RandomUnderSampler

oversample = RandomUnderSampler(sampling_strategy='majority')
x_u, y_u = oversample.fit_resample(x_train, y_train)

# %%
y_u.value_counts()
# Out:
# 0    135
# 1    135
# Name: outcome, dtype: int64

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=5, n_estimators=100)
clf.fit(x_u, y_u)
pre = clf.predict(x_test)
print(classification_report(y_test, pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84       212
#            1       0.25      0.79      0.38        24
#
#     accuracy                           0.74       236
#    macro avg       0.61      0.76      0.61       236
# weighted avg       0.90      0.74      0.79       236
